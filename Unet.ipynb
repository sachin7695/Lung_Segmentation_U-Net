# %% [markdown]
# <a href="https://colab.research.google.com/github/sachin7695/Lung_Segmentation/blob/main/Unet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
sys.path.insert(0,'/content/drive/MyDrive/Colab Notebooks/Lung_Segment')

# %%
import model
import metrics

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import cv2
from glob import glob
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Recall, Precision
from model import build_unet
from metrics import dice_loss, dice_coef, iou

""" Global parameters """
H = 512
W = 512

def create_dir(path):
    """ Create a directory. """
    if not os.path.exists(path):
        os.makedirs(path)

def load_data(path, split=0.1):
    images = sorted(glob(os.path.join(path, "CXR_png", "*.png")))
    masks1 = sorted(glob(os.path.join(path, "ManualMask", "leftMask", "*.png")))
    masks2 = sorted(glob(os.path.join(path, "ManualMask", "rightMask", "*.png")))

    split_size = int(len(images) * split)

    train_x, valid_x = train_test_split(images, test_size=split_size, random_state=42)
    train_y1, valid_y1 = train_test_split(masks1, test_size=split_size, random_state=42)
    train_y2, valid_y2 = train_test_split(masks2, test_size=split_size, random_state=42)

    train_x, test_x = train_test_split(train_x, test_size=split_size, random_state=42)
    train_y1, test_y1 = train_test_split(train_y1, test_size=split_size, random_state=42)
    train_y2, test_y2 = train_test_split(train_y2, test_size=split_size, random_state=42)

    return (train_x, train_y1, train_y2), (valid_x, valid_y1, valid_y2), (test_x, test_y1, test_y2)

def read_image(path):
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.resize(x, (W, H))
    x = x/255.0
    x = x.astype(np.float32)
    return x

def read_mask(path1, path2):
    x1 = cv2.imread(path1, cv2.IMREAD_GRAYSCALE)
    x2 = cv2.imread(path2, cv2.IMREAD_GRAYSCALE)
    x = x1 + x2
    x = cv2.resize(x, (W, H))
    x = x/np.max(x)
    x = x > 0.5
    x = x.astype(np.float32)
    x = np.expand_dims(x, axis=-1)
    return x

def tf_parse(x, y1, y2):
    def _parse(x, y1, y2):
        x = x.decode()
        y1 = y1.decode()
        y2 = y2.decode()

        x = read_image(x)
        y = read_mask(y1, y2)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y1, y2], [tf.float32, tf.float32])
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 1])
    return x, y

def tf_dataset(X, Y1, Y2, batch=8):
    dataset = tf.data.Dataset.from_tensor_slices((X, Y1, Y2))
    dataset = dataset.shuffle(buffer_size=200)
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(4)
    return dataset

if __name__ == "__main__":
    """ Seeding """
    np.random.seed(42)
    tf.random.set_seed(42)

    """ Directory for storing files """
    create_dir("files")

    """ Hyperparameters """
    batch_size = 2
    lr = 1e-5
    num_epochs = 30
    model_path = os.path.join("files", "model.h5")
    csv_path = os.path.join("files", "data.csv")

    """ Dataset """
    dataset_path = "/content/drive/MyDrive/Colab Notebooks/Lung_Segment/NLM-MontgomeryCXRSet/MontgomerySet"
    (train_x, train_y1, train_y2), (valid_x, valid_y1, valid_y2), (test_x, test_y1, test_y2) = load_data(dataset_path)

    print(f"Train: {len(train_x)} - {len(train_y1)} - {len(train_y2)}")
    print(f"Valid: {len(valid_x)} - {len(valid_y1)} - {len(valid_y2)}")
    print(f"Test: {len(test_x)} - {len(test_y1)} - {len(test_y2)}")

    train_dataset = tf_dataset(train_x, train_y1, train_y2, batch=batch_size)
    valid_dataset = tf_dataset(valid_x, valid_y1, valid_y2, batch=batch_size)

    """ Model """
    model = build_unet((H, W, 3))
    metrics = [dice_coef, iou, Recall(), Precision()]
    model.compile(loss=dice_loss, optimizer=Adam(lr), metrics=metrics)

    callbacks = [
        ModelCheckpoint(model_path, verbose=1, save_best_only=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=1e-7, verbose=1),
        CSVLogger(csv_path)
    ]

    model.fit(
        train_dataset,
        epochs=num_epochs,
        validation_data=valid_dataset,
        callbacks=callbacks
    )
# Out:
# Train: 112 - 112 - 112
# Valid: 13 - 13 - 13
# Test: 13 - 13 - 13
# Epoch 1/30
# 56/56 [==============================] - ETA: 0s - loss: 0.5702 - dice_coef: 0.4298 - iou: 0.2780 - recall_1: 0.6587 - precision_1: 0.4490
# Epoch 1: val_loss improved from inf to 0.66813, saving model to files/model.h5
# 56/56 [==============================] - 51s 850ms/step - loss: 0.5702 - dice_coef: 0.4298 - iou: 0.2780 - recall_1: 0.6587 - precision_1: 0.4490 - val_loss: 0.6681 - val_dice_coef: 0.3258 - val_iou: 0.1959 - val_recall_1: 0.0683 - val_precision_1: 0.2605 - lr: 1.0000e-05
# Epoch 2/30
# 56/56 [==============================] - ETA: 0s - loss: 0.3610 - dice_coef: 0.6390 - iou: 0.4736 - recall_1: 0.9093 - precision_1: 0.6488
# Epoch 2: val_loss improved from 0.66813 to 0.66082, saving model to files/model.h5
# 56/56 [==============================] - 47s 828ms/step - loss: 0.3610 - dice_coef: 0.6390 - iou: 0.4736 - recall_1: 0.9093 - precision_1: 0.6488 - val_loss: 0.6608 - val_dice_coef: 0.3346 - val_iou: 0.2023 - val_recall_1: 0.3516 - val_precision_1: 0.3663 - lr: 1.0000e-05
# Epoch 3/30
# 56/56 [==============================] - ETA: 0s - loss: 0.2333 - dice_coef: 0.7667 - iou: 0.6247 - recall_1: 0.9582 - precision_1: 0.8597
# Epoch 3: val_loss did not improve from 0.66082
# 56/56 [==============================] - 46s 812ms/step - loss: 0.2333 - dice_coef: 0.7667 - iou: 0.6247 - recall_1: 0.9582 - precision_1: 0.8597 - val_loss: 0.7080 - val_dice_coef: 0.2883 - val_iou: 0.1687 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - lr: 1.0000e-05
# Epoch 4/30
# 56/56 [==============================] - ETA: 0s - loss: 0.1729 - dice_coef: 0.8271 - iou: 0.7084 - recall_1: 0.9663 - precision_1: 0.9289
# Epoch 4: val_loss did not improve from 0.66082
# 56/56 [==============================] - 46s 814ms/step - loss: 0.1729 - dice_coef: 0.8271 - iou: 0.7084 - recall_1: 0.9663 - precision_1: 0.9289 - val_loss: 0.7633 - val_dice_coef: 0.2326 - val_iou: 0.1320 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - lr: 1.0000e-05
# Epoch 5/30
# 56/56 [==============================] - ETA: 0s - loss: 0.1405 - dice_coef: 0.8595 - iou: 0.7553 - recall_1: 0.9698 - precision_1: 0.9466
# Epoch 5: val_loss did not improve from 0.66082
# 56/56 [==============================] - 46s 814ms/step - loss: 0.1405 - dice_coef: 0.8595 - iou: 0.7553 - recall_1: 0.9698 - precision_1: 0.9466 - val_loss: 0.8167 - val_dice_coef: 0.1846 - val_iou: 0.1019 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - lr: 1.0000e-05
# Epoch 6/30
# 56/56 [==============================] - ETA: 0s - loss: 0.1229 - dice_coef: 0.8771 - iou: 0.7829 - recall_1: 0.9705 - precision_1: 0.9561
# Epoch 6: val_loss did not improve from 0.66082
# 56/56 [==============================] - 46s 813ms/step - loss: 0.1229 - dice_coef: 0.8771 - iou: 0.7829 - recall_1: 0.9705 - precision_1: 0.9561 - val_loss: 0.8521 - val_dice_coef: 0.1471 - val_iou: 0.0794 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - lr: 1.0000e-05
# Epoch 7/30
# 56/56 [==============================] - ETA: 0s - loss: 0.1107 - dice_coef: 0.8893 - iou: 0.8019 - recall_1: 0.9731 - precision_1: 0.9631
# Epoch 7: val_loss did not improve from 0.66082
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 56/56 [==============================] - 46s 817ms/step - loss: 0.1107 - dice_coef: 0.8893 - iou: 0.8019 - recall_1: 0.9731 - precision_1: 0.9631 - val_loss: 0.8643 - val_dice_coef: 0.1368 - val_iou: 0.0736 - val_recall_1: 0.0117 - val_precision_1: 0.7982 - lr: 1.0000e-05
# Epoch 8/30
# 56/56 [==============================] - ETA: 0s - loss: 0.1044 - dice_coef: 0.8956 - iou: 0.8126 - recall_1: 0.9772 - precision_1: 0.9661
# Epoch 8: val_loss improved from 0.66082 to 0.53949, saving model to files/model.h5
# 56/56 [==============================] - 47s 839ms/step - loss: 0.1044 - dice_coef: 0.8956 - iou: 0.8126 - recall_1: 0.9772 - precision_1: 0.9661 - val_loss: 0.5395 - val_dice_coef: 0.4801 - val_iou: 0.3292 - val_recall_1: 0.3399 - val_precision_1: 0.9714 - lr: 1.0000e-06
# Epoch 9/30
# 56/56 [==============================] - ETA: 0s - loss: 0.0990 - dice_coef: 0.9010 - iou: 0.8207 - recall_1: 0.9794 - precision_1: 0.9683
# Epoch 9: val_loss improved from 0.53949 to 0.22520, saving model to files/model.h5
# 56/56 [==============================] - 47s 835ms/step - loss: 0.0990 - dice_coef: 0.9010 - iou: 0.8207 - recall_1: 0.9794 - precision_1: 0.9683 - val_loss: 0.2252 - val_dice_coef: 0.7747 - val_iou: 0.6330 - val_recall_1: 0.7679 - val_precision_1: 0.9560 - lr: 1.0000e-06
# Epoch 10/30
# 56/56 [==============================] - ETA: 0s - loss: 0.1023 - dice_coef: 0.8977 - iou: 0.8158 - recall_1: 0.9779 - precision_1: 0.9693
# Epoch 10: val_loss improved from 0.22520 to 0.14128, saving model to files/model.h5
# 56/56 [==============================] - 48s 850ms/step - loss: 0.1023 - dice_coef: 0.8977 - iou: 0.8158 - recall_1: 0.9779 - precision_1: 0.9693 - val_loss: 0.1413 - val_dice_coef: 0.8515 - val_iou: 0.7438 - val_recall_1: 0.9380 - val_precision_1: 0.9320 - lr: 1.0000e-06
# Epoch 11/30
# 56/56 [==============================] - ETA: 0s - loss: 0.1006 - dice_coef: 0.8994 - iou: 0.8186 - recall_1: 0.9779 - precision_1: 0.9696
# Epoch 11: val_loss improved from 0.14128 to 0.12909, saving model to files/model.h5
# 56/56 [==============================] - 47s 837ms/step - loss: 0.1006 - dice_coef: 0.8994 - iou: 0.8186 - recall_1: 0.9779 - precision_1: 0.9696 - val_loss: 0.1291 - val_dice_coef: 0.8729 - val_iou: 0.7759 - val_recall_1: 0.9538 - val_precision_1: 0.9250 - lr: 1.0000e-06
# Epoch 12/30
# 56/56 [==============================] - ETA: 0s - loss: 0.1015 - dice_coef: 0.8985 - iou: 0.8180 - recall_1: 0.9790 - precision_1: 0.9688
# Epoch 12: val_loss did not improve from 0.12909
# 56/56 [==============================] - 46s 809ms/step - loss: 0.1015 - dice_coef: 0.8985 - iou: 0.8180 - recall_1: 0.9790 - precision_1: 0.9688 - val_loss: 0.1349 - val_dice_coef: 0.8680 - val_iou: 0.7716 - val_recall_1: 0.9556 - val_precision_1: 0.9278 - lr: 1.0000e-06
# Epoch 13/30
# 56/56 [==============================] - ETA: 0s - loss: 0.0991 - dice_coef: 0.9009 - iou: 0.8209 - recall_1: 0.9781 - precision_1: 0.9690
# Epoch 13: val_loss improved from 0.12909 to 0.11829, saving model to files/model.h5
# 56/56 [==============================] - 47s 833ms/step - loss: 0.0991 - dice_coef: 0.9009 - iou: 0.8209 - recall_1: 0.9781 - precision_1: 0.9690 - val_loss: 0.1183 - val_dice_coef: 0.8833 - val_iou: 0.7928 - val_recall_1: 0.9596 - val_precision_1: 0.9367 - lr: 1.0000e-06
# Epoch 14/30
# 56/56 [==============================] - ETA: 0s - loss: 0.0993 - dice_coef: 0.9007 - iou: 0.8209 - recall_1: 0.9794 - precision_1: 0.9702
# Epoch 14: val_loss improved from 0.11829 to 0.11802, saving model to files/model.h5
# 56/56 [==============================] - 47s 837ms/step - loss: 0.0993 - dice_coef: 0.9007 - iou: 0.8209 - recall_1: 0.9794 - precision_1: 0.9702 - val_loss: 0.1180 - val_dice_coef: 0.8841 - val_iou: 0.7940 - val_recall_1: 0.9585 - val_precision_1: 0.9422 - lr: 1.0000e-06
# Epoch 15/30
# 56/56 [==============================] - ETA: 0s - loss: 0.0970 - dice_coef: 0.9030 - iou: 0.8244 - recall_1: 0.9800 - precision_1: 0.9711
# Epoch 15: val_loss improved from 0.11802 to 0.11248, saving model to files/model.h5
# 56/56 [==============================] - 47s 834ms/step - loss: 0.0970 - dice_coef: 0.9030 - iou: 0.8244 - recall_1: 0.9800 - precision_1: 0.9711 - val_loss: 0.1125 - val_dice_coef: 0.8851 - val_iou: 0.7949 - val_recall_1: 0.9550 - val_precision_1: 0.9518 - lr: 1.0000e-06
# Epoch 16/30
# 56/56 [==============================] - ETA: 0s - loss: 0.0958 - dice_coef: 0.9042 - iou: 0.8261 - recall_1: 0.9799 - precision_1: 0.9707
# Epoch 16: val_loss improved from 0.11248 to 0.11133, saving model to files/model.h5
# 56/56 [==============================] - 48s 848ms/step - loss: 0.0958 - dice_coef: 0.9042 - iou: 0.8261 - recall_1: 0.9799 - precision_1: 0.9707 - val_loss: 0.1113 - val_dice_coef: 0.8905 - val_iou: 0.8034 - val_recall_1: 0.9531 - val_precision_1: 0.9565 - lr: 1.0000e-06
# Epoch 17/30
# 56/56 [==============================] - ETA: 0s - loss: 0.0948 - dice_coef: 0.9052 - iou: 0.8279 - recall_1: 0.9787 - precision_1: 0.9730
# Epoch 17: val_loss did not improve from 0.11133
# 56/56 [==============================] - 46s 809ms/step - loss: 0.0948 - dice_coef: 0.9052 - iou: 0.8279 - recall_1: 0.9787 - precision_1: 0.9730 - val_loss: 0.1142 - val_dice_coef: 0.8881 - val_iou: 0.8012 - val_recall_1: 0.9583 - val_precision_1: 0.9497 - lr: 1.0000e-06
# Epoch 18/30
# 56/56 [==============================] - ETA: 0s - loss: 0.0971 - dice_coef: 0.9029 - iou: 0.8243 - recall_1: 0.9799 - precision_1: 0.9700
# Epoch 18: val_loss did not improve from 0.11133
# 56/56 [==============================] - 45s 801ms/step - loss: 0.0971 - dice_coef: 0.9029 - iou: 0.8243 - recall_1: 0.9799 - precision_1: 0.9700 - val_loss: 0.1145 - val_dice_coef: 0.8873 - val_iou: 0.8000 - val_recall_1: 0.9488 - val_precision_1: 0.9618 - lr: 1.0000e-06
# Epoch 19/30
# 56/56 [==============================] - ETA: 0s - loss: 0.0930 - dice_coef: 0.9070 - iou: 0.8307 - recall_1: 0.9792 - precision_1: 0.9735
# Epoch 19: val_loss did not improve from 0.11133
# 56/56 [==============================] - 45s 797ms/step - loss: 0.0930 - dice_coef: 0.9070 - iou: 0.8307 - recall_1: 0.9792 - precision_1: 0.9735 - val_loss: 0.1119 - val_dice_coef: 0.8910 - val_iou: 0.8051 - val_recall_1: 0.9569 - val_precision_1: 0.9524 - lr: 1.0000e-06
# Epoch 20/30
# 56/56 [==============================] - ETA: 0s - loss: 0.0930 - dice_coef: 0.9070 - iou: 0.8309 - recall_1: 0.9805 - precision_1: 0.9720
# Epoch 20: val_loss improved from 0.11133 to 0.10728, saving model to files/model.h5
# 56/56 [==============================] - 47s 829ms/step - loss: 0.0930 - dice_coef: 0.9070 - iou: 0.8309 - recall_1: 0.9805 - precision_1: 0.9720 - val_loss: 0.1073 - val_dice_coef: 0.8899 - val_iou: 0.8024 - val_recall_1: 0.9535 - val_precision_1: 0.9587 - lr: 1.0000e-06
# Epoch 21/30
# 56/56 [==============================] - ETA: 0s - loss: 0.0940 - dice_coef: 0.9060 - iou: 0.8297 - recall_1: 0.9801 - precision_1: 0.9732
# Epoch 21: val_loss did not improve from 0.10728
# 56/56 [==============================] - 45s 802ms/step - loss: 0.0940 - dice_coef: 0.9060 - iou: 0.8297 - recall_1: 0.9801 - precision_1: 0.9732 - val_loss: 0.1116 - val_dice_coef: 0.8919 - val_iou: 0.8074 - val_recall_1: 0.9563 - val_precision_1: 0.9549 - lr: 1.0000e-06
# Epoch 22/30
# 56/56 [==============================] - ETA: 0s - loss: 0.0930 - dice_coef: 0.9070 - iou: 0.8312 - recall_1: 0.9808 - precision_1: 0.9731
# Epoch 22: val_loss did not improve from 0.10728
# 56/56 [==============================] - 45s 802ms/step - loss: 0.0930 - dice_coef: 0.9070 - iou: 0.8312 - recall_1: 0.9808 - precision_1: 0.9731 - val_loss: 0.1113 - val_dice_coef: 0.8911 - val_iou: 0.8051 - val_recall_1: 0.9549 - val_precision_1: 0.9564 - lr: 1.0000e-06
# Epoch 23/30
# 56/56 [==============================] - ETA: 0s - loss: 0.0938 - dice_coef: 0.9062 - iou: 0.8308 - recall_1: 0.9807 - precision_1: 0.9727
# Epoch 23: val_loss improved from 0.10728 to 0.10641, saving model to files/model.h5
# 56/56 [==============================] - 47s 829ms/step - loss: 0.0938 - dice_coef: 0.9062 - iou: 0.8308 - recall_1: 0.9807 - precision_1: 0.9727 - val_loss: 0.1064 - val_dice_coef: 0.8909 - val_iou: 0.8045 - val_recall_1: 0.9570 - val_precision_1: 0.9555 - lr: 1.0000e-06
# Epoch 24/30
# 56/56 [==============================] - ETA: 0s - loss: 0.0932 - dice_coef: 0.9068 - iou: 0.8312 - recall_1: 0.9805 - precision_1: 0.9747
# Epoch 24: val_loss did not improve from 0.10641
# 56/56 [==============================] - 45s 802ms/step - loss: 0.0932 - dice_coef: 0.9068 - iou: 0.8312 - recall_1: 0.9805 - precision_1: 0.9747 - val_loss: 0.1116 - val_dice_coef: 0.8903 - val_iou: 0.8055 - val_recall_1: 0.9568 - val_precision_1: 0.9563 - lr: 1.0000e-06
# Epoch 25/30
# 56/56 [==============================] - ETA: 0s - loss: 0.0895 - dice_coef: 0.9105 - iou: 0.8369 - recall_1: 0.9818 - precision_1: 0.9738
# Epoch 25: val_loss did not improve from 0.10641
# 56/56 [==============================] - 45s 801ms/step - loss: 0.0895 - dice_coef: 0.9105 - iou: 0.8369 - recall_1: 0.9818 - precision_1: 0.9738 - val_loss: 0.1095 - val_dice_coef: 0.8846 - val_iou: 0.7961 - val_recall_1: 0.9553 - val_precision_1: 0.9584 - lr: 1.0000e-06
# Epoch 26/30
# 56/56 [==============================] - ETA: 0s - loss: 0.0893 - dice_coef: 0.9107 - iou: 0.8372 - recall_1: 0.9817 - precision_1: 0.9739
# Epoch 26: val_loss improved from 0.10641 to 0.10421, saving model to files/model.h5
# 56/56 [==============================] - 47s 831ms/step - loss: 0.0893 - dice_coef: 0.9107 - iou: 0.8372 - recall_1: 0.9817 - precision_1: 0.9739 - val_loss: 0.1042 - val_dice_coef: 0.8975 - val_iou: 0.8147 - val_recall_1: 0.9548 - val_precision_1: 0.9601 - lr: 1.0000e-06
# Epoch 27/30
# 56/56 [==============================] - ETA: 0s - loss: 0.0874 - dice_coef: 0.9126 - iou: 0.8401 - recall_1: 0.9816 - precision_1: 0.9752
# Epoch 27: val_loss did not improve from 0.10421
# 56/56 [==============================] - 45s 798ms/step - loss: 0.0874 - dice_coef: 0.9126 - iou: 0.8401 - recall_1: 0.9816 - precision_1: 0.9752 - val_loss: 0.1078 - val_dice_coef: 0.8945 - val_iou: 0.8113 - val_recall_1: 0.9550 - val_precision_1: 0.9586 - lr: 1.0000e-06
# Epoch 28/30
# 56/56 [==============================] - ETA: 0s - loss: 0.0873 - dice_coef: 0.9127 - iou: 0.8405 - recall_1: 0.9830 - precision_1: 0.9741
# Epoch 28: val_loss did not improve from 0.10421
# 56/56 [==============================] - 45s 795ms/step - loss: 0.0873 - dice_coef: 0.9127 - iou: 0.8405 - recall_1: 0.9830 - precision_1: 0.9741 - val_loss: 0.1068 - val_dice_coef: 0.8951 - val_iou: 0.8117 - val_recall_1: 0.9540 - val_precision_1: 0.9601 - lr: 1.0000e-06
# Epoch 29/30
# 56/56 [==============================] - ETA: 0s - loss: 0.0871 - dice_coef: 0.9129 - iou: 0.8408 - recall_1: 0.9815 - precision_1: 0.9755
# Epoch 29: val_loss improved from 0.10421 to 0.10336, saving model to files/model.h5
# 56/56 [==============================] - 46s 817ms/step - loss: 0.0871 - dice_coef: 0.9129 - iou: 0.8408 - recall_1: 0.9815 - precision_1: 0.9755 - val_loss: 0.1034 - val_dice_coef: 0.8992 - val_iou: 0.8179 - val_recall_1: 0.9556 - val_precision_1: 0.9598 - lr: 1.0000e-06
# Epoch 30/30
# 56/56 [==============================] - ETA: 0s - loss: 0.0863 - dice_coef: 0.9137 - iou: 0.8421 - recall_1: 0.9815 - precision_1: 0.9759
# Epoch 30: val_loss did not improve from 0.10336
# 56/56 [==============================] - 45s 798ms/step - loss: 0.0863 - dice_coef: 0.9137 - iou: 0.8421 - recall_1: 0.9815 - precision_1: 0.9759 - val_loss: 0.1060 - val_dice_coef: 0.8873 - val_iou: 0.8000 - val_recall_1: 0.9559 - val_precision_1: 0.9594 - lr: 1.0000e-06

# %%
model.summary()
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv2d_19 (Conv2D)             (None, 512, 512, 64  1792        ['input_2[0][0]']
#                                 )
#
#  batch_normalization_18 (BatchN  (None, 512, 512, 64  256        ['conv2d_19[0][0]']
#  ormalization)                  )
#
#  activation_18 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_18[0][0]']
#                                 )
#
#  conv2d_20 (Conv2D)             (None, 512, 512, 64  36928       ['activation_18[0][0]']
#                                 )
#
#  batch_normalization_19 (BatchN  (None, 512, 512, 64  256        ['conv2d_20[0][0]']
#  ormalization)                  )
#
#  activation_19 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_19[0][0]']
#                                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 256, 256, 64  0          ['activation_19[0][0]']
#                                 )
#
#  conv2d_21 (Conv2D)             (None, 256, 256, 12  73856       ['max_pooling2d_4[0][0]']
#                                 8)
#
#  batch_normalization_20 (BatchN  (None, 256, 256, 12  512        ['conv2d_21[0][0]']
#  ormalization)                  8)
#
#  activation_20 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_20[0][0]']
#                                 8)
#
#  conv2d_22 (Conv2D)             (None, 256, 256, 12  147584      ['activation_20[0][0]']
#                                 8)
#
#  batch_normalization_21 (BatchN  (None, 256, 256, 12  512        ['conv2d_22[0][0]']
#  ormalization)                  8)
#
#  activation_21 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_21[0][0]']
#                                 8)
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 128, 128, 12  0          ['activation_21[0][0]']
#                                 8)
#
#  conv2d_23 (Conv2D)             (None, 128, 128, 25  295168      ['max_pooling2d_5[0][0]']
#                                 6)
#
#  batch_normalization_22 (BatchN  (None, 128, 128, 25  1024       ['conv2d_23[0][0]']
#  ormalization)                  6)
#
#  activation_22 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_22[0][0]']
#                                 6)
#
#  conv2d_24 (Conv2D)             (None, 128, 128, 25  590080      ['activation_22[0][0]']
#                                 6)
#
#  batch_normalization_23 (BatchN  (None, 128, 128, 25  1024       ['conv2d_24[0][0]']
#  ormalization)                  6)
#
#  activation_23 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_23[0][0]']
#                                 6)
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 64, 64, 256)  0          ['activation_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 64, 64, 512)  1180160     ['max_pooling2d_6[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_24[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 64, 64, 512)  2359808     ['activation_24[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_25[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 32, 32, 512)  0          ['activation_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 32, 32, 1024  4719616     ['max_pooling2d_7[0][0]']
#                                 )
#
#  batch_normalization_26 (BatchN  (None, 32, 32, 1024  4096       ['conv2d_27[0][0]']
#  ormalization)                  )
#
#  activation_26 (Activation)     (None, 32, 32, 1024  0           ['batch_normalization_26[0][0]']
#                                 )
#
#  conv2d_28 (Conv2D)             (None, 32, 32, 1024  9438208     ['activation_26[0][0]']
#                                 )
#
#  batch_normalization_27 (BatchN  (None, 32, 32, 1024  4096       ['conv2d_28[0][0]']
#  ormalization)                  )
#
#  activation_27 (Activation)     (None, 32, 32, 1024  0           ['batch_normalization_27[0][0]']
#                                 )
#
#  conv2d_transpose_4 (Conv2DTran  (None, 64, 64, 512)  2097664    ['activation_27[0][0]']
#  spose)
#
#  concatenate_4 (Concatenate)    (None, 64, 64, 1024  0           ['conv2d_transpose_4[0][0]',
#                                 )                                 'activation_25[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 64, 64, 512)  4719104     ['concatenate_4[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_28[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 64, 64, 512)  2359808     ['activation_28[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_29[0][0]']
#
#  conv2d_transpose_5 (Conv2DTran  (None, 128, 128, 25  524544     ['activation_29[0][0]']
#  spose)                         6)
#
#  concatenate_5 (Concatenate)    (None, 128, 128, 51  0           ['conv2d_transpose_5[0][0]',
#                                 2)                                'activation_23[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 128, 128, 25  1179904     ['concatenate_5[0][0]']
#                                 6)
#
#  batch_normalization_30 (BatchN  (None, 128, 128, 25  1024       ['conv2d_31[0][0]']
#  ormalization)                  6)
#
#  activation_30 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_30[0][0]']
#                                 6)
#
#  conv2d_32 (Conv2D)             (None, 128, 128, 25  590080      ['activation_30[0][0]']
#                                 6)
#
#  batch_normalization_31 (BatchN  (None, 128, 128, 25  1024       ['conv2d_32[0][0]']
#  ormalization)                  6)
#
#  activation_31 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_31[0][0]']
#                                 6)
#
#  conv2d_transpose_6 (Conv2DTran  (None, 256, 256, 12  131200     ['activation_31[0][0]']
#  spose)                         8)
#
#  concatenate_6 (Concatenate)    (None, 256, 256, 25  0           ['conv2d_transpose_6[0][0]',
#                                 6)                                'activation_21[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 256, 256, 12  295040      ['concatenate_6[0][0]']
#                                 8)
#
#  batch_normalization_32 (BatchN  (None, 256, 256, 12  512        ['conv2d_33[0][0]']
#  ormalization)                  8)
#
#  activation_32 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_32[0][0]']
#                                 8)
#
#  conv2d_34 (Conv2D)             (None, 256, 256, 12  147584      ['activation_32[0][0]']
#                                 8)
#
#  batch_normalization_33 (BatchN  (None, 256, 256, 12  512        ['conv2d_34[0][0]']
#  ormalization)                  8)
#
#  activation_33 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_33[0][0]']
#                                 8)
#
#  conv2d_transpose_7 (Conv2DTran  (None, 512, 512, 64  32832      ['activation_33[0][0]']
#  spose)                         )
#
#  concatenate_7 (Concatenate)    (None, 512, 512, 12  0           ['conv2d_transpose_7[0][0]',
#                                 8)                                'activation_19[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 512, 512, 64  73792       ['concatenate_7[0][0]']
#                                 )
#
#  batch_normalization_34 (BatchN  (None, 512, 512, 64  256        ['conv2d_35[0][0]']
#  ormalization)                  )
#
#  activation_34 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_34[0][0]']
#                                 )
#
#  conv2d_36 (Conv2D)             (None, 512, 512, 64  36928       ['activation_34[0][0]']
#                                 )
#
#  batch_normalization_35 (BatchN  (None, 512, 512, 64  256        ['conv2d_36[0][0]']
#  ormalization)                  )
#
#  activation_35 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_35[0][0]']
#                                 )
#
#  conv2d_37 (Conv2D)             (None, 512, 512, 1)  65          ['activation_35[0][0]']
#
# ==================================================================================================
# Total params: 31,055,297
# Trainable params: 31,043,521
# Non-trainable params: 11,776
# __________________________________________________________________________________________________
